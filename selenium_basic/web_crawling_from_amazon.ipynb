# %%
import sys
import io
import os
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import os, warnings
import re
warnings.filterwarnings(action='ignore')

# %%
# 내가 원하는 상품의 리뷰 페이지 여러개 가져와보기

driver = webdriver.Chrome("./chromedriver_90")
url = 'https://www.amazon.com'
driver.get(url)

# 아마존 메인 페이지의 검색 버튼의 요소를 가져온다. by xpath를 이용하는 게 가장 편리하고 정확하다.

sel_search = driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]')
sel_search_btn = driver.find_element_by_xpath('//*[@id="nav-search-submit-button"]')

print(sel_search.tag_name, sel_search_btn.tag_name)
# Out:
# input input

# %%
sel_search.clear()
sel_search.send_keys('anxious people')
sel_search_btn.click()

# %%
# 첫번째 제품의 링크 가져와서 페이지로 이동하기

first_link = driver.find_element_by_xpath('//*[@id="search"]/div[1]/div/div[1]/div/span[3]/div[2]/div[1]/div/span/div/div/div[2]/div[2]/div/div[1]/h2/a')
first_link.click()

# %%
# 모든 리뷰를 보기 위한 페이지로 이동하기
all_review_link = driver.find_element_by_xpath('//*[@id="reviews-medley-footer"]/div[2]/a')
all_review_link.click()

# %%
# 10 페이지의 리뷰 데이터 크롤링해오기

all_names = []
all_scores = []
all_locations = []
all_dates = []
all_helpfuls = []
all_comments = []

for page_number in range(10):
    time.sleep(5)

    page = driver.page_source
    soup = BeautifulSoup(page, "html.parser")
    review_table = soup.find("div", id="cm_cr-review_list")
    review_list = review_table.find_all("div", class_="a-section review aok-relative")

    for review in review_list:
        # name
        name = review.find("div", class_="a-profile-content").find("span", class_="a-profile-name").text
        all_names.append(name)

        # score
        score = review.find("span", class_="a-icon-alt").text.split(" ")[0].strip()
        all_scores.append(score)

        # location & date
        location = review.find("div", class_="a-row a-spacing-none").find("span", class_="a-size-base a-color-secondary review-date").text.split("on")[0].strip()
        date = review.find("div", class_="a-row a-spacing-none").find("span", class_="a-size-base a-color-secondary review-date").text.split("on")[-1].strip()
        all_locations.append(location)
        all_dates.append(date)

        # helpful
        try:
            helpful = review.find("span", class_="a-size-base a-color-tertiary cr-vote-text").text.strip()        
        
        except:
            helpful = "0 people found this helpful"

        all_helpfuls.append(helpful)

        # comment
        comment = review.find("div", class_="a-row a-spacing-none").find("span", class_="a-size-base review-text review-text-content").text.strip()
        all_comments.append(comment)

    #1 페이지 크롤링 후 확인
    print("review number: ", len(all_comments))
    print("user: ", all_names[-1], "score:", all_scores[-1])
    print("location: ", all_locations[-1], "date: ", all_dates[-1])
    print("number of people get helped: ", all_helpfuls[-1])
    print("comment: ", all_comments[-1], end="\n\n")

    # 다음 페이지 이동
    next_page_link = driver.find_element_by_xpath('//*[@id="cm_cr-pagination_bar"]/ul/li[2]/a')
    next_page_link.click()
# Out:
# review number:  10
# user:  Lynn K. score: 3.0
# location:  Reviewed in the United States date:  September 19, 2020
# number of people get helped:  35 people found this helpful
# comment:  I wanted to like this book and there are some startling and amusing insights, but it was too annoying to read.  With a rambling story line and mostly annoying characters it quickly becomes too tedious.
#
# review number:  20
# user:  victoria hill score: 1.0
# location:  Reviewed in the United States date:  September 18, 2020
# number of people get helped:  19 people found this helpful
# comment:  i hated this book so stupid. i found no humor at all.
#
# review number:  30
# user:  olmy score: 2.0
# location:  Reviewed in the United States date:  October 22, 2020
# number of people get helped:  7 people found this helpful
# comment:  the beginning of the story was nice, that's why I bought it, but then it goes into the same thing over and over again. You know after the first 20 pages what's going on and then it drags along. You wait for something to happen, but it comes back to the same thing, over and over. The ending is a little bit surprising, if as somebody would have said, 'please put  at least some spice to the ending, otherwise you can forget the book'. I read OVE from this author and kind of liked it. This was another reason to buy it, but somehow his style is repeating. It was in certain respect OVE with different people. For me it was the last book I read from him. Maybe he can only write one thing. A good author should be more versatile.
#
# review number:  40
# user:  David W Putnam score: 4.0
# location:  Reviewed in the United States date:  January 16, 2021
# number of people get helped:  2 people found this helpful
# comment:  This author has a great talent and I will read anything he writes.I loved, loved A Man Called Ov so maybe my expectations were set a little too high on Anxious People. I did enjoy this book a great deal and would recommend it to anyone. The concept is unique, a bank robbery investigated by a father and son and their conflicts. This would’ve been five stars had the backstory of “The bank robber,” not been in second person. This structure not only stopped the forward motion of the story but for me it was like fingernails on a chalkboard. I have no problem with first person, third person and third person close, second person tossed me out of the story and held me at arm’s length.In the first part of the book the author doesn’t stay with anyone character long enough for the reader to relate to them. For me this is critically important for establishing what I need most out of a book, The Fictive Dream, a state where I become immersed in the story. During the opening pages of most books authors are tasked with endearing the reader to the character, what I’ve heard described as, “Patting the head of the dog.”The big reason this book works and is so popular is the author’s credibility, he is a wonderful talent who readers trust implicitly and are willing to give him a few pages to set up the story. The book really digs in on page 107 so hold out a little longer if tempted to put it down, you won’t regret it. Four out of five stars.David Putnam author of the Bruno Johnson Series
#
# review number:  50
# user:  Kindle Customer score: 5.0
# location:  Reviewed in the United States date:  September 16, 2020
# number of people get helped:  3 people found this helpful
# comment:  In a time that feels like we are more distant that ever from each - Backman reminds us of the goodness of humanity.  I am an avid reader and Backman's books are by far my favorite - this book is no exception.  While this one took me a while to get into due to the narrative style - I soon could not put it down.  As others have mentioned - this is not the story of a kidnapping but about kindness among strangers.  Read it - you will not regret it.
#
# review number:  60
# user:  Book Club Member score: 5.0
# location:  Reviewed in the United States date:  December 13, 2020
# number of people get helped:  0 people found this helpful
# comment:  Not since I read O. Henry's short story "The Ransom of Red Chief" had I encountered a fictitious hostage-taker with such tremendous  regrets . In that famous story, the kidnappers seeking ransom actually have to pay an unruly boy's father to take the kid off their hands.  Backman's "Anxious People" offers a different type of  irony revealed at a more deliberate pace. Backman takes readers on a roller coaster ride of emotions that people undergo in everyday disappointments in careers, marriages, and finances  and in more traumatic situations like witnessing suicides, being present at a bank robbery, or being taken hostage. Readers will encounter both pathos and humor.Backman tells the tale from the points of view of the policemen who are called to the scene, the bank robber turned hostage-taker, and the individual hostages who are attending an Open House for an apartment that is for sale.  Things are never what they seem, and Backman teases readers with slowly-revealed details that make all the difference. The bank robber's description of the hostages as the "worst ever" is what reminded me of O. Henry's story. Few readers could ever imagine the surprise ending. I loved it!
#
# review number:  70
# user:  Gadfly21 score: 3.0
# location:  Reviewed in the United States date:  October 19, 2020
# number of people get helped:  3 people found this helpful
# comment:  Writing almost too cute. I read his big hit and loved it. But this one is just too adorable, unless the real feeling was lost in translation. The character studies are good, his human values are good, but its just too cute. Sorry I spent the money.
#
# review number:  80
# user:  Ron score: 2.0
# location:  Reviewed in the United States date:  March 23, 2021
# number of people get helped:  0 people found this helpful
# comment:  I’m in the minority here, this was just not a book I enjoyed.  There were parts of the book that kept my attention, but very few.  Humor was sprinkled through out the beginning but I kept losing momentum reading because of the jumping around of the story.  I never really got a true sense of the story, its “take away” if you will.  This is not a dig against the writer, there was some very clever pieces to the story, but it didn’t hold my attention and frankly I couldn’t wait for it to end.  The end of the book did absolutely nothing for me, but again I think it was about just wanting it to end.I can’t recommend nor will I recommend this book.  Other works from the author I enjoyed...but not this one.  Something just got lost in the translation for me.
#
# review number:  90
# user:  Amazon Customer score: 1.0
# location:  Reviewed in the United States date:  September 18, 2020
# number of people get helped:  6 people found this helpful
# comment:  The book had too much rambling about nothing and the story was very strange... It wasn't like his other books that I really enjoyed.
#
# review number:  100
# user:  N. Dahiya score: 5.0
# location:  Reviewed in the United States date:  March 13, 2021
# number of people get helped:  0 people found this helpful
# comment:  It started of as a simple disconnected story, I thought the dots would never connect and it’s a very superficial read.It made a about turn a third of the way and then kept becoming engrossing and with so much depth, one could drown trying to decipher the meaning.Has a lot of truth to what some may call cliches. I would recommend this to anyone who reads ... it’s a story about us all. We could identify with any one or more of the circumstances and people in the book.We just have to keep moving on in life always doing our best and believe that we are doing our best.

# %%
print(len(all_names))
print(len(all_scores))
print(len(all_locations))
print(len(all_dates))
print(len(all_helpfuls))
print(len(all_comments))

name_dict= {"name": all_names}
score_dict = {"score": all_scores}
location_dict = {"location": all_locations}
date_dict = {"date": all_dates}
helpful_dict = {"helpful": all_helpfuls}
comment_dict = {"comment": all_comments}

name_df = pd.DataFrame(name_dict)
score_df = pd.DataFrame(score_dict)
location_df = pd.DataFrame(location_dict)
date_df = pd.DataFrame(date_dict)
helpful_df = pd.DataFrame(helpful_dict)
comment_df = pd.DataFrame(comment_dict)

review_df = pd.concat([name_df, score_df, location_df, date_df, helpful_df, comment_df], axis=1)
review_df
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
#                   name score                       location  \
# 0       Bianca Trevino   5.0  Reviewed in the United States
# 1                Patti   5.0  Reviewed in the United States
# 2         cocochanel20   5.0  Reviewed in the United States
# 3             Schinnie   2.0  Reviewed in the United States
# 4   Denice J. Lipscomb   5.0  Reviewed in the United States
# ..                 ...   ...                            ...
# 95              Shud49   2.0  Reviewed in the United States
# 96              Sheila   5.0  Reviewed in the United States
# 97  Retired in Florida   5.0  Reviewed in the United States
# 98           J. Kuntze   5.0  Reviewed in the United States
# 99           N. Dahiya   5.0  Reviewed in the United States
#
#                   date                        helpful  \
# 0    September 8, 2020  322 people found this helpful
# 1   September 12, 2020  198 people found this helpful
# 2    September 9, 2020  191 people found this helpful
# 3   September 30, 2020  144 people found this helpful
# 4   September 14, 2020  132 people found this helpful
# ..                 ...                            ...
# 95    October 21, 2020    2 people found this helpful
# 96  September 24, 2020  One person found this helpful
# 97        May 21, 2021    0 people found this helpful
# 98    November 1, 2020    0 people found this helpful
# 99      March 13, 2021    0 people found this helpful
#
#                                               comment
# 0   I'm a little biased but Backman can do no wron...
# 1   Oh my gosh I loved this book - more than I lov...
# 2   This book had a complex start and set up but i...
# 3   Oh my gosh is this the same Fredrik Bachman wh...
# 4   I read this book in two days. I had to force m...
# ..                                                ...
# 95  Something I rarely, very rarely do. Got 51% th...
# 96  So often when I've read all of an author their...
# 97  Bachman has the Scandinavian dry, sardonic hum...
# 98  There are many writers who have something to s...
# 99  It started of as a simple disconnected story, ...
#
# [100 rows x 6 columns]

# %%
review_df.to_excel("book anxious people review data.xlsx")
review_df.to_csv("book anxious people review data.csv")
